# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
def import_file_to_dataframe(file_path):
    """
    Reads a CSV file and returns the data as a pandas dataframe.
    Args:
        file_path (str): The path to the CSV file.    
    Returns:
        A panda DataFrame representing the CSV data.
    """
    file = Path(file_path)
    df = pd.read_csv(file, index_col="Date", parse_dates=True, infer_datetime_format=True)
    df = df.sort_index(ascending=True)
    return df

# %%
# Reading whale returns
whale_returns_dataframe = import_file_to_dataframe("Resources/whale_returns.csv")
whale_returns_dataframe.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_returns_dataframe.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns_dataframe = whale_returns_dataframe.dropna()

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
algo_returns_dataframe = import_file_to_dataframe("Resources/algo_returns.csv")
algo_returns_dataframe.head(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# 2014-06-04 -0.001838       NaN
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735

# %%
# Count nulls
algo_returns_dataframe.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns_dataframe = algo_returns_dataframe.dropna()

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sp_tsx_history_dataframe = import_file_to_dataframe("Resources/sp_tsx_history.csv")
sp_tsx_history_dataframe.head()
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99

# %%
# Check Data Types
pd.DataFrame(sp_tsx_history_dataframe).dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp_tsx_history_dataframe["Close"] = sp_tsx_history_dataframe["Close"].str.strip("$")
sp_tsx_history_dataframe["Close"] = sp_tsx_history_dataframe["Close"].replace(',','', regex=True)
sp_tsx_history_dataframe["Close"] = sp_tsx_history_dataframe["Close"].astype("float")
sp_tsx_history_dataframe.head()
# Out:
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99

# %%
# Calculate Daily Returns
sp_tsx_history_dataframe["Close"] = sp_tsx_history_dataframe["Close"].pct_change()

# %%
# Drop nulls
sp_tsx_history_dataframe = sp_tsx_history_dataframe.dropna()

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_tsx_history_dataframe = sp_tsx_history_dataframe.rename(columns={"Close": "S&P TSX 60"})

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
portfolio_return_df = pd.concat([whale_returns_dataframe,algo_returns_dataframe, sp_tsx_history_dataframe], axis = "columns",join = "inner")
portfolio_return_df.head(5)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  S&P TSX 60
# Date
# 2015-03-03 -0.000949   -0.008530
# 2015-03-04  0.002416   -0.003371
# 2015-03-05  0.004323    0.001344
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
portfolio_return_df.plot(figsize=(14,7), title="Daily Returns")
# Out:
# <Axes: title={'center': 'Daily Returns'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
portfolio_cumulative_return_df = (1 + portfolio_return_df).cumprod() - 1
# Plot cumulative returns
portfolio_cumulative_return_df.plot(figsize=(14,7), title="Cumulative Returns")
# Out:
# <Axes: title={'center': 'Cumulative Returns'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
portfolio_return_df.boxplot(figsize=(14,7))
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
portfolio_daily_std = portfolio_return_df.std()
portfolio_daily_std.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# S&P TSX 60                     0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
sp_tsx_daily_std = portfolio_return_df["S&P TSX 60"].std()
# Determine which portfolios are riskier than the S&P TSX 60
higher_std = portfolio_daily_std[portfolio_daily_std > sp_tsx_daily_std]
higher_std.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
portfolio_annualized_std = portfolio_daily_std * np.sqrt(252)
portfolio_annualized_std.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# Algo 1                         0.120470
# Algo 2                         0.132177
# S&P TSX 60                     0.111664
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
portfolio_window_std = portfolio_return_df.rolling(window=21).std()
# Plot the rolling standard deviation
portfolio_window_std.plot(figsize=(14,7), title="Rolling Standard Deviation at a 21-day window")
# Out:
# <Axes: title={'center': 'Rolling Standard Deviation at a 21-day window'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
portfolio_correlation = portfolio_return_df.corr()
# Display de correlation matrix
sns.heatmap(portfolio_correlation, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
covariance = portfolio_return_df['SOROS FUND MANAGEMENT LLC'].rolling(window=30).cov(portfolio_return_df['S&P TSX 60'])
# Calculate variance of S&P TSX
variance = portfolio_return_df["S&P TSX 60"].rolling(window=30).var()
# Computing beta
beta = covariance / variance
# Plot beta trend
beta.plot(figsize=(20, 10), title='Beta 30-Day SOROS FUND MANAGEMENT LLC vs S&P TSX 60 Returns')
# Out:
# <Axes: title={'center': 'Beta 30-Day SOROS FUND MANAGEMENT LLC vs S&P TSX 60 Returns'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
portfolio_ewm =  portfolio_return_df.ewm(halflife=21).std()
portfolio_ewm.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                   0.002472            0.005814
# 2015-03-05                   0.002677            0.004968
# 2015-03-06                   0.005349            0.004615
# 2015-03-09                   0.004638            0.004471
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN       NaN
# 2015-03-04                     0.001441                0.007624  0.004700
# 2015-03-05                     0.002478                0.007020  0.004162
# 2015-03-06                     0.004665                0.009387  0.003419
# 2015-03-09                     0.005496                0.008066  0.002999
#
#               Algo 2  S&P TSX 60
# Date
# 2015-03-03       NaN         NaN
# 2015-03-04  0.002380    0.003648
# 2015-03-05  0.002662    0.004936
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
portifolio_annualized_ratio = (portfolio_return_df.mean() * 252) / (portfolio_return_df.std() * np.sqrt(252))
portifolio_annualized_ratio.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# S&P TSX 60                     0.195550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
portifolio_annualized_ratio.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
# Algo 1 performance strongly outperforms against whale and tsx60 portfolios

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
google_df = import_file_to_dataframe("Resources/GOOG.csv")
google_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-03-02  27.949764  28.529173  27.861008  28.488785  28.488785  42592618
# 2015-03-03  28.444407  28.690729  28.248444  28.603470  28.603470  34095352
# 2015-03-04  28.515211  28.776493  28.322741  28.590006  28.590006  37536775
# 2015-03-05  28.672279  28.816385  28.592001  28.687738  28.687738  27792094
# 2015-03-06  28.665298  28.755053  28.260410  28.306534  28.306534  33182854

# %%
# Reading data from 2nd stock
shell_df = import_file_to_dataframe("Resources/SHEL.csv")
shell_df.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2015-03-02  64.879997  64.940002  63.900002  64.300003  41.208336  4226585
# 2015-03-03  63.160000  63.535000  63.029999  63.299999  40.567448  7895542
# 2015-03-04  62.840000  63.055000  62.220001  62.919998  40.323925  3720261
# 2015-03-05  62.540001  62.610001  62.209999  62.340000  39.952217  2632006
# 2015-03-06  61.480000  61.660000  61.009998  61.040001  39.119083  3335327

# %%
# Reading data from 3rd stock
unilever_df = import_file_to_dataframe("Resources/ULVR.csv")
unilever_df.head()
# Out:
#               Open         High      Low   Close    Adj Close   Volume
# Date
# 2015-03-02  2864.0  2895.149902  2860.00  2875.0  2187.441650  2434992
# 2015-03-03  2889.0  2914.000000  2865.25  2871.0  2184.398438  2818827
# 2015-03-04  2867.0  2882.879883  2846.00  2880.0  2191.246094  2002740
# 2015-03-05  2880.0  2915.000000  2873.00  2913.0  2216.354004  3477736
# 2015-03-06  2908.0  2920.000000  2871.00  2871.0  2184.398438  2964860

# %%
# Combine all stocks in a single DataFrame
stocks_df = {"GOOG": google_df, "SHEL": shell_df, 'ULVR':unilever_df}
portfolio_concat_df = pd.concat(stocks_df.values(),  keys=stocks_df.keys(),  axis="columns", join="inner")
portfolio_concat_df.head()
# Out:
#                  GOOG                                                        \
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2015-03-02  27.949764  28.529173  27.861008  28.488785  28.488785  42592618
# 2015-03-03  28.444407  28.690729  28.248444  28.603470  28.603470  34095352
# 2015-03-04  28.515211  28.776493  28.322741  28.590006  28.590006  37536775
# 2015-03-05  28.672279  28.816385  28.592001  28.687738  28.687738  27792094
# 2015-03-06  28.665298  28.755053  28.260410  28.306534  28.306534  33182854
#
#                  SHEL                                                       \
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2015-03-02  64.879997  64.940002  63.900002  64.300003  41.208336  4226585
# 2015-03-03  63.160000  63.535000  63.029999  63.299999  40.567448  7895542
# 2015-03-04  62.840000  63.055000  62.220001  62.919998  40.323925  3720261
# ...

# %%
# Reset Date index
#### Reset for what reason? #####
portfolio_reseted_df = portfolio_df.reset_index()
portfolio_reseted_df.head()
# Out:
#         Date       GOOG       SHEL    ULVR
# 0 2015-03-02  28.488785  64.300003  2875.0
# 1 2015-03-03  28.603470  63.299999  2871.0
# 2 2015-03-04  28.590006  62.919998  2880.0
# 3 2015-03-05  28.687738  62.340000  2913.0
# 4 2015-03-06  28.306534  61.040001  2871.0

# %%
# Reorganize portfolio data by having a column per symbol
portfolio_df = pd.DataFrame()
portfolio_df["GOOG"] = portfolio_concat_df["GOOG"]["Close"]
portfolio_df["SHEL"] = portfolio_concat_df["SHEL"]["Close"]
portfolio_df["ULVR"] = portfolio_concat_df["ULVR"]["Close"]
portfolio_df.head()
# Out:
#                  GOOG       SHEL    ULVR
# Date
# 2015-03-02  28.488785  64.300003  2875.0
# 2015-03-03  28.603470  63.299999  2871.0
# 2015-03-04  28.590006  62.919998  2880.0
# 2015-03-05  28.687738  62.340000  2913.0
# 2015-03-06  28.306534  61.040001  2871.0

# %%
# Calculate daily returns
portfolio_daily_df = portfolio_df.pct_change()
# Drop NAs
portfolio_daily_df = portfolio_daily_df.dropna()
# Display sample data
portfolio_daily_df.head()
# Out:
#                 GOOG      SHEL      ULVR
# Date
# 2015-03-03  0.004026 -0.015552 -0.001391
# 2015-03-04 -0.000471 -0.006003  0.003135
# 2015-03-05  0.003418 -0.009218  0.011458
# 2015-03-06 -0.013288 -0.020853 -0.014418
# 2015-03-09  0.002052  0.001802 -0.014977

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]
portfolio_weighted = portfolio_df.dot(weights)

# Calculate portfolio return
### Daily? Annually? Cumulative? What type of return? ###
# portfolio_weighted_cumulative = (1 + portfolio_weighted).cumprod()
portfolio_weighted = portfolio_weighted.pct_change()

# Display sample data
portfolio_weighted = portfolio_weighted.dropna()
portfolio_weighted.head()
# Out:
# Date
# 2015-03-03   -0.001646
# 2015-03-04    0.002905
# 2015-03-05    0.010943
# 2015-03-06   -0.014541
# 2015-03-09   -0.014469
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
portfolio_weighted = portfolio_weighted.rename("Custom")
all_portfolios_df = pd.concat([portfolio_return_df, portfolio_weighted], axis="columns", join="inner")

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
all_portfolios_df = all_portfolios_df.dropna()
all_portfolios_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  S&P TSX 60    Custom
# Date
# 2015-03-03 -0.000949   -0.008530 -0.001646
# 2015-03-04  0.002416   -0.003371  0.002905
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
all_portfolios_daily_std = all_portfolios_df.std()
all_portfolios_annualized_std = all_portfolios_daily_std * np.sqrt(252)
all_portfolios_annualized_std.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.124350
# PAULSON & CO.INC.              0.111156
# TIGER GLOBAL MANAGEMENT LLC    0.172737
# BERKSHIRE HATHAWAY INC         0.204071
# Algo 1                         0.120659
# Algo 2                         0.132613
# S&P TSX 60                     0.112041
# Custom                         0.196831
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
all_portfolios_window_std = all_portfolios_df.rolling(window=21).std()
# Plot rolling standard deviation
all_portfolios_window_std.plot(figsize=(14,7), title="Rolling Standard Deviation at a 21-day window")
# Out:
# <Axes: title={'center': 'Rolling Standard Deviation at a 21-day window'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
all_portfolios_correlation = all_portfolios_df.corr()
sns.heatmap(all_portfolios_correlation, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta
covariance = all_portfolios_df['S&P TSX 60'].rolling(window=60).cov(all_portfolios_df['Custom'])
variance = all_portfolios_df["Custom"].rolling(window=60).var()
beta = covariance / variance
beta.plot(figsize=(20, 10), title='Beta 60-Day S&P TSX 60 vs Custom Returns')
# Out:
# <Axes: title={'center': 'Beta 60-Day S&P TSX 60 vs Custom Returns'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
all_portifolio_annualized_ratio = (all_portfolios_df.mean() * 252) / (all_portfolios_df.std() * np.sqrt(252))
all_portifolio_annualized_ratio.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.289402
# PAULSON & CO.INC.             -0.508580
# TIGER GLOBAL MANAGEMENT LLC   -0.147609
# BERKSHIRE HATHAWAY INC         0.463026
# Algo 1                         1.519652
# Algo 2                         0.404736
# S&P TSX 60                     0.180529
# Custom                         0.592660
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
all_portifolio_annualized_ratio.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!
